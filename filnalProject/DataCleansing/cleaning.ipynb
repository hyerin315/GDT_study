# %%
import pandas as pd

# %%
df = pd.read_csv("./instagramData/crawling01.csv")

# %%
df
# Out:
#       Unnamed: 0                   id                       date like  \
# 0              0           the_stamp1  2021-07-08 00:00:00+00:00   영상
# 1              1              __luv_j  2021-05-30 00:00:00+00:00   영상
# 2              2           miseo_0526  2021-05-16 00:00:00+00:00   영상
# 3              3      yoonsom._.story  2021-05-27 00:00:00+00:00   영상
# 4              4       e_mulgun.today  2021-04-29 00:00:00+00:00   영상
# ...          ...                  ...                        ...  ...
# 1181        1181           homerunc_s  2021-07-06 00:00:00+00:00   영상
# 1182        1182       white365_yatab  2021-07-06 00:00:00+00:00   영상
# 1183        1183        bonjour__momo  2021-07-06 00:00:00+00:00   영상
# 1184        1184  commontone.official  2021-07-06 00:00:00+00:00   영상
# 1185        1185       white365_yatab  2021-07-06 00:00:00+00:00   영상
#
#                                                    text  \
# 0     코코넛비누 포득포득 넘좋아요🙃 . Reposted from @say.nature _...
# ...

# %%
df = df.sort_values(by=['date'], axis=0)

# %%
df
# Out:
#     Unnamed: 0                  id                       date like  \
# 5            5  thebutler.official  2021-04-24 00:00:00+00:00   영상
# 4            4      e_mulgun.today  2021-04-29 00:00:00+00:00   영상
# 7            7          sylove7100  2021-05-12 00:00:00+00:00   영상
# 2            2          miseo_0526  2021-05-16 00:00:00+00:00   영상
# 3            3     yoonsom._.story  2021-05-27 00:00:00+00:00   영상
# ..         ...                 ...                        ...  ...
# 33          33      the.zone_clean  2021-08-16 00:00:00+00:00   영상
# 31          31          30ml.store  2021-08-16 00:00:00+00:00   영상
# 30          30      lovely_twins07  2021-08-16 00:00:00+00:00   영상
# 28          28      white365_yatab  2021-08-16 00:00:00+00:00   영상
# 43          43          haruhanjib  2021-08-16 00:00:00+00:00   영상
#
#                                                  text  \
# 5   . <올바르지 않으면 만들지 않습니다> 즐거운 주일 신나는 주일 빨래해야 하는데, ...
# ...

# %%
# Out:
#      Unnamed: 0           id                       date like  \
# 286         286  me.heeeeeee  2021-08-09 00:00:00+00:00  좋아요
# 164         164     _tayo___  2021-08-13 00:00:00+00:00  좋아요
#
#                                                   text  \
# 286  메이썸 런드리겔 간편하게 휴대하면서 들고다닐수 있는 세제입니다! 아이에게도 안전한 ...
# 164  @blomberg_kr 핏!독일명품 식기세척기 자연유래성분이라 안심되고 세척력 또한...
#
#                                                hashtag
# 286  ['#오라랩', '#메이썸', '#메이썸런드리겔', '#천연세제', '#친환경세제'...
# 164  ['#협찬', '#fit', '#핏세제', '#독일명품세제', '#식기세척기세제',...
